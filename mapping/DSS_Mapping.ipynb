# %% [markdown]
# # DSS Model Mapping

# %% [markdown]
# ### Imports

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import re
from datetime import date

# %% [markdown]
# ### Load DSS Model from Excel

# %%
RAW_DSS_MAP_EXCEL = Path("../data/input/CRDC DST Cross-Model Mapping.xlsx")

# %%
raw_df = pd.read_excel(
    RAW_DSS_MAP_EXCEL,
    sheet_name="CRDC DST Cross-Model Mapping",
    header=2,
    nrows=1529,
    usecols=["DST Data Element Name", "Compiled Data Element Names"]
)
# Out:
# c:\ProgramData\Anaconda3\envs\bento_test_3_8\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
raw_df
# Out:
#        DST Data Element Name  \
# 0         Subject Identifier
# 1              Specimen Type
# 2         Subject Ethnicity*
# 3               Subject Race
# 4                        NaN
# ...                      ...
# 1524             Tumor Grade
# 1525             Tumor Grade
# 1526                     NaN
# 1527  Disease Clinical Stage
# 1528           Exposure Type
#
#                             Compiled Data Element Names
# 0     CTDC.case.case_id\nGDC.Case.id\nICDC.case.case...
# 1     GDC.Sample.sample_type\nICDC.sample.physical_s...
# 2     CTDC.case.ethnicity\nGDC.Demographic.ethnicity...
# 3     CTDC.case.race\nGDC.Demographic.race\nPDC.Demo...
# 4     GDC.Diagnosis.site_of_resection_or_biopsy\nIDC...
# ...                                                 ...
# 1524                        PDC.Diagnosis.who_nte_grade
# 1525               PDC.Diagnosis.gleason_grade_tertiary
# 1526  GDC.Diagnosis.tumor_depth\nPDC.Diagnosis.tumor...
# 1527            PDC.Diagnosis.figo_staging_edition_year
# 1528                         PDC.Exposure.exposure_type
#
# [1529 rows x 2 columns]

# %% [markdown]
# ### Separate DSS & Other Models

# %%
# model for dst nodes
df_dss = pd.DataFrame(np.repeat("DSS", len(raw_df)))

df_dss = pd.concat(
    [df_dss, raw_df["DST Data Element Name"].str.split(" ", 1, expand=True)],
    axis=1
)
df_dss.columns = ["ent_1_model", "ent_1_extra_handles", "ent_1_handle"]
df_dss = df_dss[["ent_1_model", "ent_1_handle", "ent_1_extra_handles"]]
# df_dst["ent_1_extra_handles"] = [[l] for l in df_dst["ent_1_extra_handles"]] # listify extra handles

# %%
df_dss
# Out:
#      ent_1_model    ent_1_handle ent_1_extra_handles
# 0            DSS      Identifier             Subject
# 1            DSS            Type            Specimen
# 2            DSS      Ethnicity*             Subject
# 3            DSS            Race             Subject
# 4            DSS             NaN                 NaN
# ...          ...             ...                 ...
# 1524         DSS           Grade               Tumor
# 1525         DSS           Grade               Tumor
# 1526         DSS             NaN                 NaN
# 1527         DSS  Clinical Stage             Disease
# 1528         DSS            Type            Exposure
#
# [1529 rows x 3 columns]

# %%
df_models = raw_df["Compiled Data Element Names"].str.strip().str.split(
    '\n', 
    expand=True
).add_prefix("Model_Data_Element_Name_")

df_models
# Out:
#                       Model_Data_Element_Name_0  \
# 0                             CTDC.case.case_id
# 1                        GDC.Sample.sample_type
# 2                           CTDC.case.ethnicity
# 3                                CTDC.case.race
# 4     GDC.Diagnosis.site_of_resection_or_biopsy
# ...                                         ...
# 1524                PDC.Diagnosis.who_nte_grade
# 1525       PDC.Diagnosis.gleason_grade_tertiary
# 1526                  GDC.Diagnosis.tumor_depth
# 1527    PDC.Diagnosis.figo_staging_edition_year
# 1528                 PDC.Exposure.exposure_type
#
#               Model_Data_Element_Name_1  \
# 0                           GDC.Case.id
# 1     ICDC.sample.physical_sample_type
# 2             GDC.Demographic.ethnicity
# 3                  GDC.Demographic.race
# 4           IDC.TCIA.tcia_tumorLocation
# ...                                 ...
# 1524                               None
# 1525                               None
# 1526          PDC.Diagnosis.tumor_depth
# 1527                               None
# 1528                               None
#
#                             Model_Data_Element_Name_2  \
# 0                                   ICDC.case.case_id
# 1                              PDC.Sample.sample_type
# 2     IDC.DICOM.Patient Module.Patient's Ethnic Group
# 3                                PDC.Demographic.race
# 4           PDC.Diagnosis.site_of_resection_or_biopsy
# ...                                               ...
# 1524                                             None
# 1525                                             None
# 1526                                             None
# 1527                                             None
# 1528                                             None
#
#                               Model_Data_Element_Name_3  \
# 0                   IDC.DICOM.Patient Module.Patient ID
# 1                    CDS.Sample Information.sample_type
# 2                             PDC.Demographic.ethnicity
# 3                                  CDS.Participant.race
# 4     CDS.Additional Diagnosis Information.site_of_r...
# ...                                                 ...
# 1524                                               None
# 1525                                               None
# 1526                                               None
# 1527                                               None
# 1528                                               None
#
#                        Model_Data_Element_Name_4  \
# 0                               PDC.Case.case_id
# 1              CDA.Specimen.source_material_type
# 2                      CDS.Participant.ethnicity
# 3                               CDA.Patient.race
# 4     HTAN.Diagnosis.site_of_resection_or_biopsy
# ...                                          ...
# 1524                                        None
# 1525                                        None
# 1526                                        None
# 1527                                        None
# 1528                                        None
#
#                  Model_Data_Element_Name_5    Model_Data_Element_Name_6  \
# 0               CDS.Participant.subject_id   CDA.Patient.dct:identifier
# 1     HTAN.Molecular Test.biospecimen_type    C2M2.biosample.assay_type
# 2                    CDA.Patient.ethnicity  HTAN.Demographics.Ethnicity
# 3                   HTAN.Demographics.Race       C2M2.subject_race.race
# 4                                     None                         None
# ...                                    ...                          ...
# 1524                                  None                         None
# 1525                                  None                         None
# 1526                                  None                         None
# 1527                                  None                         None
# 1528                                  None                         None
#
#                 Model_Data_Element_Name_7 Model_Data_Element_Name_8  \
# 0                                           C2M2.biosample.local_id
# 1     mCODE.Genomic Specimen Profile.Type                      None
# 2                  C2M2.subject.ethnicity                      None
# 3                                    None                      None
# 4                                    None                      None
# ...                                   ...                       ...
# 1524                                 None                      None
# 1525                                 None                      None
# 1526                                 None                      None
# 1527                                 None                      None
# 1528                                 None                      None
#
#                     Model_Data_Element_Name_9
# 0     mCODE.Cancer Patient Profile.Identifier
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 1524                                     None
# 1525                                     None
# 1526                                     None
# 1527                                     None
# 1528                                     None
#
# [1529 rows x 10 columns]

# %%
df_dss.join(df_models)
# Out:
#      ent_1_model    ent_1_handle ent_1_extra_handles  \
# 0            DSS      Identifier             Subject
# 1            DSS            Type            Specimen
# 2            DSS      Ethnicity*             Subject
# 3            DSS            Race             Subject
# 4            DSS             NaN                 NaN
# ...          ...             ...                 ...
# 1524         DSS           Grade               Tumor
# 1525         DSS           Grade               Tumor
# 1526         DSS             NaN                 NaN
# 1527         DSS  Clinical Stage             Disease
# 1528         DSS            Type            Exposure
#
#                       Model_Data_Element_Name_0  \
# 0                             CTDC.case.case_id
# 1                        GDC.Sample.sample_type
# 2                           CTDC.case.ethnicity
# 3                                CTDC.case.race
# 4     GDC.Diagnosis.site_of_resection_or_biopsy
# ...                                         ...
# 1524                PDC.Diagnosis.who_nte_grade
# 1525       PDC.Diagnosis.gleason_grade_tertiary
# 1526                  GDC.Diagnosis.tumor_depth
# 1527    PDC.Diagnosis.figo_staging_edition_year
# 1528                 PDC.Exposure.exposure_type
#
#               Model_Data_Element_Name_1  \
# 0                           GDC.Case.id
# 1     ICDC.sample.physical_sample_type
# 2             GDC.Demographic.ethnicity
# 3                  GDC.Demographic.race
# 4           IDC.TCIA.tcia_tumorLocation
# ...                                 ...
# 1524                               None
# 1525                               None
# 1526          PDC.Diagnosis.tumor_depth
# 1527                               None
# 1528                               None
#
#                             Model_Data_Element_Name_2  \
# 0                                   ICDC.case.case_id
# 1                              PDC.Sample.sample_type
# 2     IDC.DICOM.Patient Module.Patient's Ethnic Group
# 3                                PDC.Demographic.race
# 4           PDC.Diagnosis.site_of_resection_or_biopsy
# ...                                               ...
# 1524                                             None
# 1525                                             None
# 1526                                             None
# 1527                                             None
# 1528                                             None
#
#                               Model_Data_Element_Name_3  \
# 0                   IDC.DICOM.Patient Module.Patient ID
# 1                    CDS.Sample Information.sample_type
# 2                             PDC.Demographic.ethnicity
# 3                                  CDS.Participant.race
# 4     CDS.Additional Diagnosis Information.site_of_r...
# ...                                                 ...
# 1524                                               None
# 1525                                               None
# 1526                                               None
# 1527                                               None
# 1528                                               None
#
#                        Model_Data_Element_Name_4  \
# 0                               PDC.Case.case_id
# 1              CDA.Specimen.source_material_type
# 2                      CDS.Participant.ethnicity
# 3                               CDA.Patient.race
# 4     HTAN.Diagnosis.site_of_resection_or_biopsy
# ...                                          ...
# 1524                                        None
# 1525                                        None
# 1526                                        None
# 1527                                        None
# 1528                                        None
#
#                  Model_Data_Element_Name_5    Model_Data_Element_Name_6  \
# 0               CDS.Participant.subject_id   CDA.Patient.dct:identifier
# 1     HTAN.Molecular Test.biospecimen_type    C2M2.biosample.assay_type
# 2                    CDA.Patient.ethnicity  HTAN.Demographics.Ethnicity
# 3                   HTAN.Demographics.Race       C2M2.subject_race.race
# 4                                     None                         None
# ...                                    ...                          ...
# 1524                                  None                         None
# 1525                                  None                         None
# 1526                                  None                         None
# 1527                                  None                         None
# 1528                                  None                         None
#
#                 Model_Data_Element_Name_7 Model_Data_Element_Name_8  \
# 0                                           C2M2.biosample.local_id
# 1     mCODE.Genomic Specimen Profile.Type                      None
# 2                  C2M2.subject.ethnicity                      None
# 3                                    None                      None
# 4                                    None                      None
# ...                                   ...                       ...
# 1524                                 None                      None
# 1525                                 None                      None
# 1526                                 None                      None
# 1527                                 None                      None
# 1528                                 None                      None
#
#                     Model_Data_Element_Name_9
# 0     mCODE.Cancer Patient Profile.Identifier
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 1524                                     None
# 1525                                     None
# 1526                                     None
# 1527                                     None
# 1528                                     None
#
# [1529 rows x 13 columns]

# %% [markdown]
# ### Drop duplicates in whole set of mappings

# %%
# check for duplicates in whole df, drop 2nd occurance
df_both = df_dss.join(df_models)
df_both.drop_duplicates(keep="first", inplace=True)
dss_df = df_both[["ent_1_model", "ent_1_handle", "ent_1_extra_handles"]]
df_models = df_both.drop(["ent_1_model", "ent_1_handle", "ent_1_extra_handles"], axis=1)
print(len(dss_df), len(df_models))
# Out:
# 1522 1522

# %%
df_models.count()
# Out:
# Model_Data_Element_Name_0    1520
# Model_Data_Element_Name_1     394
# Model_Data_Element_Name_2     243
# Model_Data_Element_Name_3      66
# Model_Data_Element_Name_4      32
# Model_Data_Element_Name_5      18
# Model_Data_Element_Name_6      10
# Model_Data_Element_Name_7       4
# Model_Data_Element_Name_8       2
# Model_Data_Element_Name_9       1
# dtype: int64

# %%
# look at row with 9 "mappings"
for i, x in enumerate(df_models.count(axis=1)):
    if x >= 9:
        print(i, x)
# Out:
# 0 10
# 48 9

# %%
df_models.iloc[[48]]
# Out:
#                Model_Data_Element_Name_0 Model_Data_Element_Name_1  \
# 48  GDC.Sample.biospecimen_anatomic_site   ICDC.sample.sample_site
#
#                            Model_Data_Element_Name_2  \
# 48  IDC.DICOM.General Series Module.BodyPartExamined
#
#                Model_Data_Element_Name_3  \
# 48  PDC.Sample.biospecimen_anatomic_site
#
#                             Model_Data_Element_Name_4  \
# 48  CDS.Additional Sample Information.sample_anato...
#
#        Model_Data_Element_Name_5 Model_Data_Element_Name_6  \
# 48  CDA.Specimen.anatomical_site
#
#    Model_Data_Element_Name_7  \
# 48    C2M2.biosample.anatomy
#
#                             Model_Data_Element_Name_8  \
# 48  mCODE.Genomic Specimen Profile.Collection > Bo...
#
#    Model_Data_Element_Name_9
# 48                      None

# %% [markdown]
# ### Stack rows of matches into one column

# %%
df_models_stack = pd.DataFrame(df_models.stack())

# %%
df_models_stack.head()
# Out:
#                                                                0
# 0 Model_Data_Element_Name_0                    CTDC.case.case_id
#   Model_Data_Element_Name_1                          GDC.Case.id
#   Model_Data_Element_Name_2                    ICDC.case.case_id
#   Model_Data_Element_Name_3  IDC.DICOM.Patient Module.Patient ID
#   Model_Data_Element_Name_4                     PDC.Case.case_id

# %%
# get rid of "model data element name" column
df_models_stack = df_models_stack.droplevel(-1)

# %%
df_models_stack.head()
# Out:
#                                      0
# 0                    CTDC.case.case_id
# 0                          GDC.Case.id
# 0                    ICDC.case.case_id
# 0  IDC.DICOM.Patient Module.Patient ID
# 0                     PDC.Case.case_id

# %% [markdown]
# Note: index here aligns with index of DSS property

# %%
len(df_models_stack)
# Out:
# 2290

# %% [markdown]
# ### Clean stacked models df

# %% [markdown]
# ##### Drop any missing rows

# %%
# drop any missing rows
df_models_stack.dropna(subset=[0], inplace=True)

# %%
len(df_models_stack)
# Out:
# 2290

# %% [markdown]
# No missing values found here, but some incorrectly coded

# %% [markdown]
# ##### Replace non-breaking spaces and empty strings with null and drop nulls again

# %%
df_models_stack[0].replace(u"\xa0", np.nan, inplace=True)
df_models_stack[0].replace(u"", np.nan, inplace=True)

# %%
df_models_stack.dropna(subset=[0], inplace=True)

# %%
len(df_models_stack)
# Out:
# 2257

# %% [markdown]
# 33 empty rows dropped this time

# %%
df_models_stack.head()
# Out:
#                                      0
# 0                    CTDC.case.case_id
# 0                          GDC.Case.id
# 0                    ICDC.case.case_id
# 0  IDC.DICOM.Patient Module.Patient ID
# 0                     PDC.Case.case_id

# %% [markdown]
# ##### Separate stacked models df into model, node, & prop handles

# %%
df_models_split = df_models_stack[0].str.split(".", expand=True)

# %%
df_models_split.count()
# Out:
# 0    2257
# 1    2257
# 2    2227
# 3      15
# dtype: int64

# %%
# df_models rows with a third option (what should be node and what should be property?)
df_models_other_1 = df_models_split.loc[df_models_split[3].notnull()]
df_models_other_1
# Out:
#        0                   1                      2                       3
# 0    IDC               DICOM         Patient Module              Patient ID
# 2    IDC               DICOM         Patient Module  Patient's Ethnic Group
# 10   IDC               DICOM         Patient Module  Patient's Ethnic Group
# 29   IDC               DICOM         Patient Module           Patient's Sex
# 48   IDC               DICOM  General Series Module        BodyPartExamined
# 271  IDC               DICOM   Patient Study Module             Patient Age
# 517  IDC               DICOM   Patient Study Module          Patient's Size
# 518  IDC               DICOM   Patient Study Module        Patient's Weight
# 519  IDC               DICOM  General Series Module               StudyDate
# 571  GDC          SlideImage                ref:GDC    data_file_properties
# 668  GDC  ClinicalSupplement                ref:GDC    data_file_properties
# 736  GDC  ExperimentMetadata                ref:GDC    data_file_properties
# 824  GDC     PathologyReport                ref:GDC    data_file_properties
# 894  GDC   ProteinExpression                ref:GDC    data_file_properties
# 940  GDC         RunMetadata                ref:GDC    data_file_properties

# %%
# df_models without a 2nd option
df_models_other_2 = df_models_split.loc[df_models_split[1].notnull() & df_models_split[2].isnull()]
df_models_other_2
# Out:
#              0                       1     2     3
# 50        ICDC                    case  None  None
# 51        ICDC               diagnosis  None  None
# 53        ICDC                  sample  None  None
# 55        ICDC             demographic  None  None
# 56        ICDC                 program  None  None
# 57        ICDC                   study  None  None
# 75        ICDC                    file  None  None
# 79        ICDC  principal_investigator  None  None
# 134       ICDC              enrollment  None  None
# 212       ICDC                  sample  None  None
# 260       ICDC           adverse_event  None  None
# 261       ICDC               follow_up  None  None
# 404       ICDC          disease_extent  None  None
# 426   GDC desc                  ENTITY  None  None
# 426   PDC desc                  ENTITY  None  None
# 472       ICDC           prior_therapy  None  None
# 498       ICDC               study_arm  None  None
# 594       ICDC                   agent  None  None
# 598       ICDC    agent_administration  None  None
# 648       ICDC                   assay  None  None
# 671       ICDC                  cohort  None  None
# 675       ICDC                   cycle  None  None
# 765       ICDC                   image  None  None
# 802       ICDC               off_study  None  None
# 812       ICDC           off_treatment  None  None
# 827       ICDC           physical_exam  None  None
# 842       ICDC           prior_surgery  None  None
# 999       ICDC              study_site  None  None
# 1011      ICDC                   visit  None  None
# 1015      ICDC             vital_signs  None  None

# %% [markdown]
# ##### Identify duplicates in split models df

# %%
df_models_split[df_models_split.duplicated(keep=False)]
# Out:
#           0                                 1  \
# 1     mCODE          Genomic Specimen Profile
# 2      CTDC                              case
# 2       IDC                             DICOM
# 2       PDC                       Demographic
# 2       CDA                           Patient
# ...     ...                               ...
# 1425  mCODE  Primary Cancer Condition Profile
# 1426  mCODE  Primary Cancer Condition Profile
# 1430  mCODE  Primary Cancer Condition Profile
# 1502  mCODE                Tumor Size Profile
# 1507  mCODE            Tumor Specimen Profile
#
#                                         2                       3
# 1                                    Type                    None
# 2                               ethnicity                    None
# 2                          Patient Module  Patient's Ethnic Group
# 2                               ethnicity                    None
# 2                               ethnicity                    None
# ...                                   ...                     ...
# 1425                                 Code                    None
# 1426                            Body Site                    None
# 1430                                Stage                    None
# 1502  Component > Tumor Longest Dimension                    None
# 1507                           Identifier                    None
#
# [106 rows x 4 columns]

# %% [markdown]
# ##### Change model df handles to match mapping script

# %%
df_models_split.columns = ["ent_2_model", "ent_2_extra_handles", "ent_2_handle", "ent_2_handles_other"]
df_models_split = df_models_split[["ent_2_model", "ent_2_handle", "ent_2_handles_other", "ent_2_extra_handles"]]

# %% [markdown]
# ### Combine DST and other model mappings into one df

# %%
df_mappings = df_dss.join(df_models_split)

# %%
df_mappings
# Out:
#      ent_1_model    ent_1_handle ent_1_extra_handles ent_2_model  \
# 0            DSS      Identifier             Subject        CTDC
# 0            DSS      Identifier             Subject         GDC
# 0            DSS      Identifier             Subject        ICDC
# 0            DSS      Identifier             Subject         IDC
# 0            DSS      Identifier             Subject         PDC
# ...          ...             ...                 ...         ...
# 1525         DSS           Grade               Tumor         PDC
# 1526         DSS             NaN                 NaN         GDC
# 1526         DSS             NaN                 NaN         PDC
# 1527         DSS  Clinical Stage             Disease         PDC
# 1528         DSS            Type            Exposure         PDC
#
#                    ent_2_handle ent_2_handles_other ent_2_extra_handles
# 0                       case_id                None                case
# 0                            id                None                Case
# 0                       case_id                None                case
# 0                Patient Module          Patient ID               DICOM
# 0                       case_id                None                Case
# ...                         ...                 ...                 ...
# 1525     gleason_grade_tertiary                None           Diagnosis
# 1526                tumor_depth                None           Diagnosis
# 1526                tumor_depth                None           Diagnosis
# 1527  figo_staging_edition_year                None           Diagnosis
# 1528              exposure_type                None            Exposure
#
# [2266 rows x 7 columns]

# %% [markdown]
# ##### identify duplicate rows in combined df

# %%
df_mappings[df_mappings.duplicated(keep=False)]
# Out:
#      ent_1_model ent_1_handle ent_1_extra_handles ent_2_model    ent_2_handle  \
# 2            DSS   Ethnicity*             Subject        CTDC       ethnicity
# 2            DSS   Ethnicity*             Subject         IDC  Patient Module
# 2            DSS   Ethnicity*             Subject         PDC       ethnicity
# 2            DSS   Ethnicity*             Subject         CDA       ethnicity
# 10           DSS   Ethnicity*             Subject        CTDC       ethnicity
# ...          ...          ...                 ...         ...             ...
# 961          DSS          NaN                 NaN        ICDC   of_case(case)
# 962          DSS          NaN                 NaN         NaN             NaN
# 963          DSS          NaN                 NaN         NaN             NaN
# 1069         DSS          NaN                 NaN         NaN             NaN
# 1303         DSS          NaN                 NaN         NaN             NaN
#
#          ent_2_handles_other ent_2_extra_handles
# 2                       None                case
# 2     Patient's Ethnic Group               DICOM
# 2                       None         Demographic
# 2                       None             Patient
# 10                      None                case
# ...                      ...                 ...
# 961                     None              sample
# 962                      NaN                 NaN
# 963                      NaN                 NaN
# 1069                     NaN                 NaN
# 1303                     NaN                 NaN
#
# [75 rows x 7 columns]

# %%
len(df_mappings)
# Out:
# 2266

# %% [markdown]
# ##### drop duplicate rows in combined df

# %%
df_mappings.drop_duplicates(keep="first", inplace=True)

# %%
len(df_mappings)
# Out:
# 2216

# %% [markdown]
# 50 duplicate rows dropped

# %%
df_mappings
# Out:
#      ent_1_model    ent_1_handle ent_1_extra_handles ent_2_model  \
# 0            DSS      Identifier             Subject        CTDC
# 0            DSS      Identifier             Subject         GDC
# 0            DSS      Identifier             Subject        ICDC
# 0            DSS      Identifier             Subject         IDC
# 0            DSS      Identifier             Subject         PDC
# ...          ...             ...                 ...         ...
# 1525         DSS           Grade               Tumor         PDC
# 1526         DSS             NaN                 NaN         GDC
# 1526         DSS             NaN                 NaN         PDC
# 1527         DSS  Clinical Stage             Disease         PDC
# 1528         DSS            Type            Exposure         PDC
#
#                    ent_2_handle ent_2_handles_other ent_2_extra_handles
# 0                       case_id                None                case
# 0                            id                None                Case
# 0                       case_id                None                case
# 0                Patient Module          Patient ID               DICOM
# 0                       case_id                None                Case
# ...                         ...                 ...                 ...
# 1525     gleason_grade_tertiary                None           Diagnosis
# 1526                tumor_depth                None           Diagnosis
# 1526                tumor_depth                None           Diagnosis
# 1527  figo_staging_edition_year                None           Diagnosis
# 1528              exposure_type                None            Exposure
#
# [2216 rows x 7 columns]

# %% [markdown]
# ### Separate rows with missing DSS property handle

# %%
dss_mappings_other = df_mappings[df_mappings["ent_1_handle"].isna()]

# %%
dss_mappings_other
# Out:
#      ent_1_model ent_1_handle ent_1_extra_handles ent_2_model  \
# 4            DSS          NaN                 NaN         GDC
# 4            DSS          NaN                 NaN         IDC
# 4            DSS          NaN                 NaN         PDC
# 4            DSS          NaN                 NaN         CDS
# 4            DSS          NaN                 NaN        HTAN
# ...          ...          ...                 ...         ...
# 1520         DSS          NaN                 NaN       mCODE
# 1521         DSS          NaN                 NaN       mCODE
# 1522         DSS          NaN                 NaN       mCODE
# 1526         DSS          NaN                 NaN         GDC
# 1526         DSS          NaN                 NaN         PDC
#
#                      ent_2_handle ent_2_handles_other  \
# 4     site_of_resection_or_biopsy                None
# 4              tcia_tumorLocation                None
# 4     site_of_resection_or_biopsy                None
# 4     site_of_resection_or_biopsy                None
# 4     site_of_resection_or_biopsy                None
# ...                           ...                 ...
# 1520                     Location                None
# 1521           Location Qualifier                None
# 1522                      Patient                None
# 1526                  tumor_depth                None
# 1526                  tumor_depth                None
#
#                    ent_2_extra_handles
# 4                            Diagnosis
# 4                                 TCIA
# 4                            Diagnosis
# 4     Additional Diagnosis Information
# 4                            Diagnosis
# ...                                ...
# 1520                     Tumor Profile
# 1521                     Tumor Profile
# 1522                     Tumor Profile
# 1526                         Diagnosis
# 1526                         Diagnosis
#
# [1904 rows x 7 columns]

# %%
dss_mappings = df_mappings[df_mappings["ent_1_handle"].notna()]

# %%
dss_mappings
# Out:
#      ent_1_model    ent_1_handle ent_1_extra_handles ent_2_model  \
# 0            DSS      Identifier             Subject        CTDC
# 0            DSS      Identifier             Subject         GDC
# 0            DSS      Identifier             Subject        ICDC
# 0            DSS      Identifier             Subject         IDC
# 0            DSS      Identifier             Subject         PDC
# ...          ...             ...                 ...         ...
# 1523         DSS           Grade               Tumor         PDC
# 1524         DSS           Grade               Tumor         PDC
# 1525         DSS           Grade               Tumor         PDC
# 1527         DSS  Clinical Stage             Disease         PDC
# 1528         DSS            Type            Exposure         PDC
#
#                    ent_2_handle ent_2_handles_other ent_2_extra_handles
# 0                       case_id                None                case
# 0                            id                None                Case
# 0                       case_id                None                case
# 0                Patient Module          Patient ID               DICOM
# 0                       case_id                None                Case
# ...                         ...                 ...                 ...
# 1523              who_cns_grade                None           Diagnosis
# 1524              who_nte_grade                None           Diagnosis
# 1525     gleason_grade_tertiary                None           Diagnosis
# 1527  figo_staging_edition_year                None           Diagnosis
# 1528              exposure_type                None            Exposure
#
# [312 rows x 7 columns]

# %% [markdown]
# ### Fix identified issues with mappings

# %% [markdown]
# ##### Clean IDC node handles; matching to CDA definition, TBD exactly how to do in MDB as of Dec 2022

# %%
# giving IDC nodes the "file" node for now to match existing (from CDA?)
# could change to use tables from https://learn.canceridc.dev/data/organization-of-data/files-and-metadata as nodes?

dss_mappings[dss_mappings["ent_2_model"] == "IDC"]
# Out:
#     ent_1_model              ent_1_handle ent_1_extra_handles ent_2_model  \
# 0           DSS                Identifier             Subject         IDC
# 2           DSS                Ethnicity*             Subject         IDC
# 14          DSS                Identifier                File         IDC
# 15          DSS                      Name             Program         IDC
# 21          DSS                     Taxon             Subject         IDC
# 29          DSS  Gender (Gender Identity)             Subject         IDC
# 48          DSS             Anatomic Site            Specimen         IDC
# 259         DSS                Identifier             Project         IDC
# 277         DSS                  Modality             Imaging         IDC
#
#                                           ent_2_handle  \
# 0                                       Patient Module
# 2                                       Patient Module
# 14                                          source_DOI
# 15                                             Program
# 21   tcia_species (not yet available in IDC product...
# 29                                      Patient Module
# 48                               General Series Module
# 259                                      collection_id
# 277                                           Modality
#
#         ent_2_handles_other ent_2_extra_handles
# 0                Patient ID               DICOM
# 2    Patient's Ethnic Group               DICOM
# 14                     None                TCIA
# 15                     None                TCIA
# 21                     None                TCIA
# 29            Patient's Sex               DICOM
# 48         BodyPartExamined               DICOM
# 259                    None                TCIA
# 277                    None               DICOM

# %%
dss_mappings[dss_mappings["ent_2_handles_other"].notnull()]
# Out:
#    ent_1_model              ent_1_handle ent_1_extra_handles ent_2_model  \
# 0          DSS                Identifier             Subject         IDC
# 2          DSS                Ethnicity*             Subject         IDC
# 29         DSS  Gender (Gender Identity)             Subject         IDC
# 48         DSS             Anatomic Site            Specimen         IDC
#
#              ent_2_handle     ent_2_handles_other ent_2_extra_handles
# 0          Patient Module              Patient ID               DICOM
# 2          Patient Module  Patient's Ethnic Group               DICOM
# 29         Patient Module           Patient's Sex               DICOM
# 48  General Series Module        BodyPartExamined               DICOM

# %%
idc_other_handles_mask = dss_mappings["ent_2_handles_other"].notnull()
idc_other_handles = dss_mappings[dss_mappings["ent_2_handles_other"].notnull()]["ent_2_handles_other"]
dss_mappings.loc[idc_other_handles_mask, 'ent_2_handle'] = idc_other_handles
# Out:
# c:\ProgramData\Anaconda3\envs\bento_test_3_8\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# c:\ProgramData\Anaconda3\envs\bento_test_3_8\lib\site-packages\pandas\core\indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
dss_mappings[dss_mappings["ent_2_model"] == "IDC"]
# Out:
#     ent_1_model              ent_1_handle ent_1_extra_handles ent_2_model  \
# 0           DSS                Identifier             Subject         IDC
# 2           DSS                Ethnicity*             Subject         IDC
# 14          DSS                Identifier                File         IDC
# 15          DSS                      Name             Program         IDC
# 21          DSS                     Taxon             Subject         IDC
# 29          DSS  Gender (Gender Identity)             Subject         IDC
# 48          DSS             Anatomic Site            Specimen         IDC
# 259         DSS                Identifier             Project         IDC
# 277         DSS                  Modality             Imaging         IDC
#
#                                           ent_2_handle  \
# 0                                           Patient ID
# 2                               Patient's Ethnic Group
# 14                                          source_DOI
# 15                                             Program
# 21   tcia_species (not yet available in IDC product...
# 29                                       Patient's Sex
# 48                                    BodyPartExamined
# 259                                      collection_id
# 277                                           Modality
#
#         ent_2_handles_other ent_2_extra_handles
# 0                Patient ID               DICOM
# 2    Patient's Ethnic Group               DICOM
# 14                     None                TCIA
# 15                     None                TCIA
# 21                     None                TCIA
# 29            Patient's Sex               DICOM
# 48         BodyPartExamined               DICOM
# 259                    None                TCIA
# 277                    None               DICOM

# %%
dss_mappings = dss_mappings.drop(columns="ent_2_handles_other")

# %%
dss_mappings[dss_mappings["ent_2_model"] == "IDC"]
# Out:
#     ent_1_model              ent_1_handle ent_1_extra_handles ent_2_model  \
# 0           DSS                Identifier             Subject         IDC
# 2           DSS                Ethnicity*             Subject         IDC
# 14          DSS                Identifier                File         IDC
# 15          DSS                      Name             Program         IDC
# 21          DSS                     Taxon             Subject         IDC
# 29          DSS  Gender (Gender Identity)             Subject         IDC
# 48          DSS             Anatomic Site            Specimen         IDC
# 259         DSS                Identifier             Project         IDC
# 277         DSS                  Modality             Imaging         IDC
#
#                                           ent_2_handle ent_2_extra_handles
# 0                                           Patient ID               DICOM
# 2                               Patient's Ethnic Group               DICOM
# 14                                          source_DOI                TCIA
# 15                                             Program                TCIA
# 21   tcia_species (not yet available in IDC product...                TCIA
# 29                                       Patient's Sex               DICOM
# 48                                    BodyPartExamined               DICOM
# 259                                      collection_id                TCIA
# 277                                           Modality               DICOM

# %%
dss_mappings.loc[dss_mappings["ent_2_model"] == "IDC", ["ent_2_extra_handles"]] = "file"

# %%
dss_mappings[dss_mappings["ent_2_model"] == "IDC"]
# Out:
#     ent_1_model              ent_1_handle ent_1_extra_handles ent_2_model  \
# 0           DSS                Identifier             Subject         IDC
# 2           DSS                Ethnicity*             Subject         IDC
# 14          DSS                Identifier                File         IDC
# 15          DSS                      Name             Program         IDC
# 21          DSS                     Taxon             Subject         IDC
# 29          DSS  Gender (Gender Identity)             Subject         IDC
# 48          DSS             Anatomic Site            Specimen         IDC
# 259         DSS                Identifier             Project         IDC
# 277         DSS                  Modality             Imaging         IDC
#
#                                           ent_2_handle ent_2_extra_handles
# 0                                           Patient ID                file
# 2                               Patient's Ethnic Group                file
# 14                                          source_DOI                file
# 15                                             Program                file
# 21   tcia_species (not yet available in IDC product...                file
# 29                                       Patient's Sex                file
# 48                                    BodyPartExamined                file
# 259                                      collection_id                file
# 277                                           Modality                file

# %% [markdown]
# ##### Clean up other notes, etc. added to handles in raw spreadsheet

# %%
# remove extraneous notes, etc. from ent 1 handles
ent_1_pattern = "|".join([
    re.escape("*"),
    re.escape(" (same as name?)"),
    re.escape(" (?)")
])
dss_mappings["ent_1_handle"] = dss_mappings["ent_1_handle"].str.replace(ent_1_pattern, "")
# Out:
# C:\Users\nelso\AppData\Local\Temp\ipykernel_25752\1100968097.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   dss_mappings["ent_1_handle"] = dss_mappings["ent_1_handle"].str.replace(ent_1_pattern, "")

# %%
# remove extraneous notes, etc. from ent 2 handles
ent_2_pattern = "|".join([
    re.escape(" (not yet available in IDC production release)"),
    re.escape(" (Consider PhenotypicSex)"),
    re.escape("dct:"),
    re.escape("Component > "),
    re.escape("Collection > "),
    re.escape("'")
])
dss_mappings["ent_2_handle"] = dss_mappings["ent_2_handle"].str.replace(ent_2_pattern, "")
# Out:
# C:\Users\nelso\AppData\Local\Temp\ipykernel_25752\4100785705.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   dss_mappings["ent_2_handle"] = dss_mappings["ent_2_handle"].str.replace(ent_2_pattern, "")

# %%
# reset index
dss_mappings.reset_index(inplace=True, drop=True)

# %%
dss_mappings.head(20)
# Out:
#    ent_1_model ent_1_handle ent_1_extra_handles ent_2_model  \
# 0          DSS   Identifier             Subject        CTDC
# 1          DSS   Identifier             Subject         GDC
# 2          DSS   Identifier             Subject        ICDC
# 3          DSS   Identifier             Subject         IDC
# 4          DSS   Identifier             Subject         PDC
# 5          DSS   Identifier             Subject         CDS
# 6          DSS   Identifier             Subject         CDA
# 7          DSS   Identifier             Subject        C2M2
# 8          DSS   Identifier             Subject       mCODE
# 9          DSS         Type            Specimen         GDC
# 10         DSS         Type            Specimen        ICDC
# 11         DSS         Type            Specimen         PDC
# 12         DSS         Type            Specimen         CDS
# 13         DSS         Type            Specimen         CDA
# 14         DSS         Type            Specimen        HTAN
# 15         DSS         Type            Specimen        C2M2
# 16         DSS         Type            Specimen       mCODE
# 17         DSS    Ethnicity             Subject        CTDC
# 18         DSS    Ethnicity             Subject         GDC
# 19         DSS    Ethnicity             Subject         IDC
#
#              ent_2_handle       ent_2_extra_handles
# 0                 case_id                      case
# 1                      id                      Case
# 2                 case_id                      case
# 3              Patient ID                      file
# 4                 case_id                      Case
# 5              subject_id               Participant
# 6              identifier                   Patient
# 7                local_id                 biosample
# 8              Identifier    Cancer Patient Profile
# 9             sample_type                    Sample
# 10  physical_sample_type                     sample
# 11            sample_type                    Sample
# 12            sample_type        Sample Information
# 13   source_material_type                  Specimen
# 14       biospecimen_type            Molecular Test
# 15             assay_type                 biosample
# 16                   Type  Genomic Specimen Profile
# 17              ethnicity                      case
# 18              ethnicity               Demographic
# 19  Patients Ethnic Group                      file

# %% [markdown]
# ##### Clean up mCODE handles

# %%
dss_mappings[dss_mappings["ent_2_model"] == "mCODE"]
# Out:
#     ent_1_model              ent_1_handle ent_1_extra_handles ent_2_model  \
# 8           DSS                Identifier             Subject       mCODE
# 16          DSS                      Type            Specimen       mCODE
# 37          DSS                     Grade               Tumor       mCODE
# 48          DSS       general morphology               Tissue       mCODE
# 60          DSS                Identifier            Specimen       mCODE
# 83          DSS  Gender (Gender Identity)             Subject       mCODE
# 96          DSS            Clinical Stage             Disease       mCODE
# 109         DSS             Anatomic Site            Specimen       mCODE
# 128         DSS                      Site             Primary       mCODE
# 144         DSS                chromosome                Gene       mCODE
# 146         DSS                     Locus                Gene       mCODE
# 148         DSS                    symbol                Gene       mCODE
# 162         DSS      specific morphology               Tissue       mCODE
# 174         DSS         longest dimension            Specimen       mCODE
# 182         DSS          Pathologic Stage             Disease       mCODE
# 192         DSS                      Code             Disease       mCODE
# 269         DSS                    symbol                Gene       mCODE
# 270         DSS                chromosome                Gene       mCODE
# 285         DSS                Identifier            Specimen       mCODE
#
#                       ent_2_handle               ent_2_extra_handles
# 8                       Identifier            Cancer Patient Profile
# 16                            Type          Genomic Specimen Profile
# 37                           Stage  Primary Cancer Condition Profile
# 48   Histology Morphology Behavior  Primary Cancer Condition Profile
# 60                      Identifier            Tumor Specimen Profile
# 83                          Gender            Cancer Patient Profile
# 96                            Code  Primary Cancer Condition Profile
# 109                      Body Site          Genomic Specimen Profile
# 128                      Body Site  Primary Cancer Condition Profile
# 144           Cytogenetic Location           Genomic Variant Profile
# 146  Genomic Reference Sequence Id    Genomic Region Studied Profile
# 148  Genomic Reference Sequence Id    Genomic Region Studied Profile
# 162                           Code  Primary Cancer Condition Profile
# 174        Tumor Longest Dimension                Tumor Size Profile
# 182                           Code  Primary Cancer Condition Profile
# 192                      Component  Comorbidities Elixhauser Profile
# 269       Cytogenetic Nomenclature           Genomic Variant Profile
# 270  Genomic Reference Sequence Id    Genomic Region Studied Profile
# 285                     Identifier            Tumor Specimen Profile

# %%
# drop "Profile" from ent 2 node handles
ent_2_extra_pattern = "|".join([
    re.escape(" Profile"),
])
dss_mappings["ent_2_extra_handles"] = dss_mappings["ent_2_extra_handles"].str.replace(ent_2_extra_pattern, "")
# Out:
# C:\Users\nelso\AppData\Local\Temp\ipykernel_25752\2338541350.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   dss_mappings["ent_2_extra_handles"] = dss_mappings["ent_2_extra_handles"].str.replace(ent_2_extra_pattern, "")

# %%
dss_mappings[dss_mappings["ent_2_model"] == "mCODE"]
# Out:
#     ent_1_model              ent_1_handle ent_1_extra_handles ent_2_model  \
# 8           DSS                Identifier             Subject       mCODE
# 16          DSS                      Type            Specimen       mCODE
# 37          DSS                     Grade               Tumor       mCODE
# 48          DSS       general morphology               Tissue       mCODE
# 60          DSS                Identifier            Specimen       mCODE
# 83          DSS  Gender (Gender Identity)             Subject       mCODE
# 96          DSS            Clinical Stage             Disease       mCODE
# 109         DSS             Anatomic Site            Specimen       mCODE
# 128         DSS                      Site             Primary       mCODE
# 144         DSS                chromosome                Gene       mCODE
# 146         DSS                     Locus                Gene       mCODE
# 148         DSS                    symbol                Gene       mCODE
# 162         DSS      specific morphology               Tissue       mCODE
# 174         DSS         longest dimension            Specimen       mCODE
# 182         DSS          Pathologic Stage             Disease       mCODE
# 192         DSS                      Code             Disease       mCODE
# 269         DSS                    symbol                Gene       mCODE
# 270         DSS                chromosome                Gene       mCODE
# 285         DSS                Identifier            Specimen       mCODE
#
#                       ent_2_handle       ent_2_extra_handles
# 8                       Identifier            Cancer Patient
# 16                            Type          Genomic Specimen
# 37                           Stage  Primary Cancer Condition
# 48   Histology Morphology Behavior  Primary Cancer Condition
# 60                      Identifier            Tumor Specimen
# 83                          Gender            Cancer Patient
# 96                            Code  Primary Cancer Condition
# 109                      Body Site          Genomic Specimen
# 128                      Body Site  Primary Cancer Condition
# 144           Cytogenetic Location           Genomic Variant
# 146  Genomic Reference Sequence Id    Genomic Region Studied
# 148  Genomic Reference Sequence Id    Genomic Region Studied
# 162                           Code  Primary Cancer Condition
# 174        Tumor Longest Dimension                Tumor Size
# 182                           Code  Primary Cancer Condition
# 192                      Component  Comorbidities Elixhauser
# 269       Cytogenetic Nomenclature           Genomic Variant
# 270  Genomic Reference Sequence Id    Genomic Region Studied
# 285                     Identifier            Tumor Specimen

# %% [markdown]
# ##### Clean up CDA handles (to match those actually provided by CDA)

# %%
dss_mappings[dss_mappings["ent_2_model"] == "CDA"]
# Out:
#     ent_1_model            ent_1_handle ent_1_extra_handles ent_2_model  \
# 6           DSS              Identifier             Subject         CDA
# 13          DSS                    Type            Specimen         CDA
# 22          DSS               Ethnicity             Subject         CDA
# 29          DSS                    Race             Subject         CDA
# 41          DSS        Age at Diagnosis             Subject         CDA
# 46          DSS     general morphology               Tissue         CDA
# 51          DSS                  Format                File         CDA
# 59          DSS              Identifier            Specimen         CDA
# 65          DSS              Identifier                File         CDA
# 75          DSS                   Taxon             Subject         CDA
# 87          DSS                    Type                File         CDA
# 107         DSS           Anatomic Site            Specimen         CDA
# 114         DSS  Gender (PhenotypicSex)             Subject         CDA
# 122         DSS   Sex (Genotypic Sex)\n             Subject         CDA
# 133         DSS       Investigator Name           Principal         CDA
# 161         DSS    specific morphology               Tissue         CDA
# 168         DSS              Identifier             Project         CDA
# 180         DSS        Pathologic Stage             Disease         CDA
# 185         DSS          Clinical Stage             Disease         CDA
# 189         DSS                    Code             Disease         CDA
# 195         DSS                Modality             Imaging         CDA
#
#                             ent_2_handle ent_2_extra_handles
# 6                             identifier             Patient
# 13                  source_material_type            Specimen
# 22                             ethnicity             Patient
# 29                                  race             Patient
# 41                      age_at_diagnosis           Diagnosis
# 46             general_tissue_morphology            Specimen
# 51                           file_format                File
# 59                            identifier            Specimen
# 65                            identifier                File
# 75                                 taxon             Patient
# 87                             data_type                File
# 107                      anatomical_site            Specimen
# 114                                  sex             Patient
# 122                      hasGenotypicSex             Patient
# 133              isPrincipalInvestigator             Dataset
# 161           specific_tissue_morphology            Specimen
# 168                           identifier             Project
# 180                    hasDiseaseStaging           Diagnosis
# 185                    hasDiseaseStaging           Diagnosis
# 189  hasDisease?     [OntologyReference]             Patient
# 195                   hasImagingFileType                File

# %%
# CDA "Patient" node to "Subject"
cda_other_handles_mask_1 = (dss_mappings["ent_2_model"] == "CDA") & (dss_mappings["ent_2_extra_handles"] == "Patient")
dss_mappings.loc[cda_other_handles_mask_1, "ent_2_extra_handles"] = "Subject"

# %%
# CDA "taxon" property to "species"
cda_other_handles_mask_2 = (dss_mappings["ent_2_model"] == "CDA") & (dss_mappings["ent_2_handle"] == "taxon")
dss_mappings.loc[cda_other_handles_mask_2, "ent_2_handle"] = "species"

# %%
# CDA "hasDiseaseStaging" property to "stage"
cda_other_handles_mask_3 = (dss_mappings["ent_2_model"] == "CDA") & (dss_mappings["ent_2_handle"] == "hasDiseaseStaging")
dss_mappings.loc[cda_other_handles_mask_3, "ent_2_handle"] = "stage"

# %%
# CDA "identifier" property of "Project" node to "member_of_research_project" of "ResearchSubjeect"
cda_other_handles_mask_4 = (dss_mappings["ent_2_model"] == "CDA") & (dss_mappings["ent_2_extra_handles"] == "Project") & (dss_mappings["ent_2_handle"] == "identifier")
dss_mappings.loc[cda_other_handles_mask_4, "ent_2_handle"] = "member_of_research_project"
dss_mappings.loc[cda_other_handles_mask_4, "ent_2_extra_handles"] = "ResearchSubject"

# %%
dss_mappings[dss_mappings["ent_2_model"] == "CDA"]
# Out:
#     ent_1_model            ent_1_handle ent_1_extra_handles ent_2_model  \
# 6           DSS              Identifier             Subject         CDA
# 13          DSS                    Type            Specimen         CDA
# 22          DSS               Ethnicity             Subject         CDA
# 29          DSS                    Race             Subject         CDA
# 41          DSS        Age at Diagnosis             Subject         CDA
# 46          DSS     general morphology               Tissue         CDA
# 51          DSS                  Format                File         CDA
# 59          DSS              Identifier            Specimen         CDA
# 65          DSS              Identifier                File         CDA
# 75          DSS                   Taxon             Subject         CDA
# 87          DSS                    Type                File         CDA
# 107         DSS           Anatomic Site            Specimen         CDA
# 114         DSS  Gender (PhenotypicSex)             Subject         CDA
# 122         DSS   Sex (Genotypic Sex)\n             Subject         CDA
# 133         DSS       Investigator Name           Principal         CDA
# 161         DSS    specific morphology               Tissue         CDA
# 168         DSS              Identifier             Project         CDA
# 180         DSS        Pathologic Stage             Disease         CDA
# 185         DSS          Clinical Stage             Disease         CDA
# 189         DSS                    Code             Disease         CDA
# 195         DSS                Modality             Imaging         CDA
#
#                             ent_2_handle ent_2_extra_handles
# 6                             identifier             Subject
# 13                  source_material_type            Specimen
# 22                             ethnicity             Subject
# 29                                  race             Subject
# 41                      age_at_diagnosis           Diagnosis
# 46             general_tissue_morphology            Specimen
# 51                           file_format                File
# 59                            identifier            Specimen
# 65                            identifier                File
# 75                               species             Subject
# 87                             data_type                File
# 107                      anatomical_site            Specimen
# 114                                  sex             Subject
# 122                      hasGenotypicSex             Subject
# 133              isPrincipalInvestigator             Dataset
# 161           specific_tissue_morphology            Specimen
# 168           member_of_research_project     ResearchSubject
# 180                                stage           Diagnosis
# 185                                stage           Diagnosis
# 189  hasDisease?     [OntologyReference]             Subject
# 195                   hasImagingFileType                File

# %%
dss_mappings[dss_mappings["ent_2_model"] == "CDA"].shape
# Out:
# (21, 6)

# %%
# drop rows not found in official CDA mappings
cda_drop_handles =  [
    "hasGenotypicSex",
    "hasDisease?     [OntologyReference]", 
    "isPrincipalInvestigator",
    "general_tissue_morphology", 
    "specific_tissue_morphology"
]

for handle in cda_drop_handles:
    cda_drop_index = dss_mappings.loc[(dss_mappings["ent_2_model"] == "CDA") & (dss_mappings["ent_2_handle"] == handle)].index
    dss_mappings.drop(labels=cda_drop_index, inplace=True)

# %%
dss_mappings[dss_mappings["ent_2_model"] == "CDA"]
# Out:
#     ent_1_model            ent_1_handle ent_1_extra_handles ent_2_model  \
# 6           DSS              Identifier             Subject         CDA
# 13          DSS                    Type            Specimen         CDA
# 22          DSS               Ethnicity             Subject         CDA
# 29          DSS                    Race             Subject         CDA
# 41          DSS        Age at Diagnosis             Subject         CDA
# 51          DSS                  Format                File         CDA
# 59          DSS              Identifier            Specimen         CDA
# 65          DSS              Identifier                File         CDA
# 75          DSS                   Taxon             Subject         CDA
# 87          DSS                    Type                File         CDA
# 107         DSS           Anatomic Site            Specimen         CDA
# 114         DSS  Gender (PhenotypicSex)             Subject         CDA
# 168         DSS              Identifier             Project         CDA
# 180         DSS        Pathologic Stage             Disease         CDA
# 185         DSS          Clinical Stage             Disease         CDA
# 195         DSS                Modality             Imaging         CDA
#
#                    ent_2_handle ent_2_extra_handles
# 6                    identifier             Subject
# 13         source_material_type            Specimen
# 22                    ethnicity             Subject
# 29                         race             Subject
# 41             age_at_diagnosis           Diagnosis
# 51                  file_format                File
# 59                   identifier            Specimen
# 65                   identifier                File
# 75                      species             Subject
# 87                    data_type                File
# 107             anatomical_site            Specimen
# 114                         sex             Subject
# 168  member_of_research_project     ResearchSubject
# 180                       stage           Diagnosis
# 185                       stage           Diagnosis
# 195          hasImagingFileType                File

# %%
dss_mappings[dss_mappings["ent_2_model"] == "CDA"].shape
# Out:
# (16, 6)

# %% [markdown]
# 5 rows dropped b/c not in official CDA mappings

# %% [markdown]
# ##### Fix GDC, PDC, ICDC node handles to match those already in MDB

# %%
dss_mappings.ent_2_model.unique()
# Out:
# array(['CTDC', 'GDC', 'ICDC', 'IDC', 'PDC', 'CDS', 'CDA', 'C2M2', 'mCODE',
#        'HTAN', nan], dtype=object)

# %%
# convert GDC node handles to lowercase to match format in MDB
gdc_node_handles = dss_mappings[dss_mappings["ent_2_model"] == "GDC"]["ent_2_extra_handles"]
dss_mappings.loc[dss_mappings["ent_2_model"] == "GDC", "ent_2_extra_handles"] = gdc_node_handles.str.lower()

# %%
# convert ICDC node handles to lowercase to match format in MDB
icdc_node_handles = dss_mappings[dss_mappings["ent_2_model"] == "ICDC"]["ent_2_extra_handles"]
dss_mappings.loc[dss_mappings["ent_2_model"] == "ICDC", "ent_2_extra_handles"] = icdc_node_handles.str.lower()

# %%
# convert PDC node handles to lowercase to match format in MDB
pdc_node_handles = dss_mappings[dss_mappings["ent_2_model"] == "PDC"]["ent_2_extra_handles"]
dss_mappings.loc[dss_mappings["ent_2_model"] == "PDC", "ent_2_extra_handles"] = pdc_node_handles.str.lower()

# %% [markdown]
# ### Drop any rows with nulls or duplicates in cleaned df

# %%
dss_mappings.shape
# Out:
# (307, 6)

# %% [markdown]
# ##### Drop rows with a null

# %%
# drop any rows with remaining NA values
null_index = dss_mappings[dss_mappings.isnull().any(axis=1)].index
dss_mappings.drop(labels=null_index, inplace=True)

dss_mappings.shape
# Out:
# (305, 6)

# %% [markdown]
# 2 rows with null values dropped

# %% [markdown]
# ##### Drop duplicate rows

# %%
# drop any remaining duplicates
dss_mappings.drop_duplicates(keep="first", inplace=True)
dss_mappings.shape
# Out:
# (303, 6)

# %% [markdown]
# 2 duplicate rows dropped

# %% [markdown]
# ### Convert node handles to list for mapping script

# %%
dss_mappings["ent_1_extra_handles"] = [[l] for l in dss_mappings["ent_1_extra_handles"]] # listify extra handles
dss_mappings["ent_2_extra_handles"] = [[l] for l in dss_mappings["ent_2_extra_handles"]] # listify extra handles

# %%
dss_mappings.head(20)
# Out:
#    ent_1_model ent_1_handle ent_1_extra_handles ent_2_model  \
# 0          DSS   Identifier           [Subject]        CTDC
# 1          DSS   Identifier           [Subject]         GDC
# 2          DSS   Identifier           [Subject]        ICDC
# 3          DSS   Identifier           [Subject]         IDC
# 4          DSS   Identifier           [Subject]         PDC
# 5          DSS   Identifier           [Subject]         CDS
# 6          DSS   Identifier           [Subject]         CDA
# 7          DSS   Identifier           [Subject]        C2M2
# 8          DSS   Identifier           [Subject]       mCODE
# 9          DSS         Type          [Specimen]         GDC
# 10         DSS         Type          [Specimen]        ICDC
# 11         DSS         Type          [Specimen]         PDC
# 12         DSS         Type          [Specimen]         CDS
# 13         DSS         Type          [Specimen]         CDA
# 14         DSS         Type          [Specimen]        HTAN
# 15         DSS         Type          [Specimen]        C2M2
# 16         DSS         Type          [Specimen]       mCODE
# 17         DSS    Ethnicity           [Subject]        CTDC
# 18         DSS    Ethnicity           [Subject]         GDC
# 19         DSS    Ethnicity           [Subject]         IDC
#
#              ent_2_handle   ent_2_extra_handles
# 0                 case_id                [case]
# 1                      id                [case]
# 2                 case_id                [case]
# 3              Patient ID                [file]
# 4                 case_id                [case]
# 5              subject_id         [Participant]
# 6              identifier             [Subject]
# 7                local_id           [biosample]
# 8              Identifier      [Cancer Patient]
# 9             sample_type              [sample]
# 10  physical_sample_type               [sample]
# 11            sample_type              [sample]
# 12            sample_type  [Sample Information]
# 13   source_material_type            [Specimen]
# 14       biospecimen_type      [Molecular Test]
# 15             assay_type           [biosample]
# 16                   Type    [Genomic Specimen]
# 17              ethnicity                [case]
# 18              ethnicity         [demographic]
# 19  Patients Ethnic Group                [file]

# %% [markdown]
# ### Output cleaned DSS mappings (& others that couldn't be mapped properly)

# %%
output_path = Path("../data/output/")

# %%
today_date = date.today().strftime('%Y%m%d')

# %%
clean_output_path = Path(output_path, f"{today_date}_{input_filename}_clean.csv")
other_output_path = Path(output_path, f"{today_date}_{input_filename}_other.csv")

# %%
dss_mappings.to_csv(clean_output_path, index=False)
dss_mappings_other.to_csv(other_output_path, index=False)
